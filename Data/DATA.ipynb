# %%
import pandas as pd

# %%
JAN20 = pd.read_csv("JC-202001-citibike-tripdata.csv")

# %%
FEB20 = pd.read_csv("JC-202002-citibike-tripdata.csv")

# %%
MAR20 = pd.read_csv("JC-202003-citibike-tripdata.csv")

# %%
APR20 = pd.read_csv("JC-202004-citibike-tripdata.csv")

# %%
MAY20 = pd.read_csv("JC-202005-citibike-tripdata.csv")

# %%
JUN20 = pd.read_csv("JC-202006-citibike-tripdata.csv")

# %%
JUL20 = pd.read_csv("JC-202007-citibike-tripdata.csv")

# %%
AUG20 = pd.read_csv("JC-202008-citibike-tripdata.csv")

# %%
SEP20 = pd.read_csv("JC-202009-citibike-tripdata.csv")

# %%
OCT20 = pd.read_csv("JC-202010-citibike-tripdata.csv")

# %%
NOV20 = pd.read_csv("JC-202011-citibike-tripdata.csv")

# %%
citibike2020 = pd.concat([JAN20, FEB20, MAR20, APR20, MAY20, JUN20, JUL20, AUG20, SEP20, OCT20, NOV20])
citibike2020["gender"] = citibike2020["gender"].replace({0: "Unknown", 1: "Male", 2: "Female"})
citibike2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 21270           849  2020-11-30 23:08:40.1870  2020-11-30 23:22:50.0830
# 21271           370  2020-11-30 23:09:27.0180  2020-11-30 23:15:37.3330
# 21272           341  2020-11-30 23:37:53.0580  2020-11-30 23:43:34.1200
# 21273          5272  2020-11-30 23:49:31.8650  2020-12-01 01:17:24.2540
# 21274           222  2020-11-30 23:56:52.8310  2020-12-01 00:00:34.8660
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike2020.to_csv("citibike2020.csv", encoding="utf-8", index=False, header=True)
